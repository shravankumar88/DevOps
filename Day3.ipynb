# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#25. Perform all Arithmetic Opertors in Python display the output
#26. Find the aread of trinagle in Python display the output
#27. Use fstrings in python prg and display the output
#28. Creaet a list called Fruits that contain apple,banana,grapes,orsange. Check whthere grapes is in the Fruits list or not
#29. Take any two variables and check that two var refers to the smae object or not
#30. Perfrom Logical Operators in Python and display the output?

# %%
print("Hello")
# Out:
# Hello
