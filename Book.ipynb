# %% [markdown]
# ### Procedural Programming
# There are diffent type of architetural paradigms used to origanize programs
# - OOP(Object Oriented Programming)
# - Funcational Programming
# - The basic is paradigms, procedural programming : is the issuing of instructions to a computer in a ordered sequence

# %% [markdown]
# ### Functions
# - print
# - range
# if/elseif/else
# - while
# - nested if
# - contuine/break

# %%
x = 0
for i in range(3):
    x = x + (i % 2 == 0)
    print(x)
# Out:
# 1
# 1
# 2
