# %%
#62.Take a string paragraph replace is with are and the with that
replace_str = "Take a string paragraph replace are and that"
replace_str1 = replace_str.replace("are", "is").replace("that","with")
print(replace_str1)
# Out:
# Take a string paragraph replace is and with

# %%
#54.Display a list without the element 3 for the given list?List_1 =[2,3,3,3,5,6,8,15]55.Remove the element 15 by using index numberList_1 =[8,7,15,2,5,89]56.using list Comprehension create a list of odd numbers from 20 to 4057.Using List Comprehension Create a list of squares of even numbers from 20 to 3058.Take a range(10,21) and if the number is even multiply by 2 and if the number is odd then take 0 by using List comprehension display the output?59.For the given list Countries print the both the index and the value of elements during iteration.  Countries = [“India”, “Bangladesh”, “Nepal”]60.For the given list ipl_teams  print the both the index and the value of elements during iteration but start count from 1 ipl_teams = [“Srh”, “Csk,”Rcb”,”MI”]61.Take a list called numbers and and copy the elements of numbers to another list called roll numbers

# %%
#63 Ask the user to enter a senetence and print it so that the first letter of each words is uppercase and reset the letters in each works are lowercase
user_str = input("Enter a senetence")
print(user_str)
uppercase = user_str.capitalize()
print(uppercase)
uppercase1 = user_str.title()
print(uppercase1)
# Out:
# Ask the user to enter a senetence and print it
# Ask the user to enter a senetence and print it
# Ask The User To Enter A Senetence And Print It

# %%
#64'''Ask the userto enter a sentence and print the senetence with all the
#letters converted to uppercase

convert_uppercase=input("Enter the sentance")
convert_uppercase1 = convert_uppercase.upper()
print(convert_uppercase1)
# Out:
# CONVERT_UPPERCASE

# %%
#65 Ask the userto enter a sentence and print the senetence with all the
#letters converted to lowercase

convert_lowercase=input("Enter the sentance")
convert_lowercase1 = convert_lowercase.lower()
print(convert_lowercase1)
# Out:
# enter the lowercase

# %%
#66 Ask the user to enter a word how many vowels it contains
vowels = input("Enter the word")
vowels_store1 = "aeiou"
for i in vowels:
    if i == vowels_store1:
        print(i)
    # vowels2 = vowels_store1.count(i)
    # print(vowels2)

# %%
#67 Ask the user to enter a sentenase and return the same sentences without spaces at the beginning and end
no_space = input("Enter the sentence")
no_space1 = no_space.strip(" ")
print(no_space)
print(no_space1)
# Out:
#   hi
#   hi

# %%
#68 Ask the user to enter a sentenase and a word.
# Determine if the senetnce is ends with that word.
#print"Yes"if it does otherwise "No"
determine = input("Enter the sentence")
if i == determine:
    determine1 = i.endswith("word")
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#69 Enter a word and check it reads the same forwards and backwards

a = "dad"
b = a.swapcase()
print(b)
# Out:
# DAD

# %%
#70 Enter a senetnce and print it so that only the very frist letter 
# of the sentence is uppercase and reset is lowercase

# %%
#71 Dtermine if the senetbnces starts with that word print"Yes"if it does otherwise "No"
determine = input("Enter the sentence")
determine1 = determine.startswith("hi")
if i == determine1:
    print(i)
