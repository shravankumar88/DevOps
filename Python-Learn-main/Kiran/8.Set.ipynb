# %% [markdown]
# NTS - SET
# A set is a collection which is unordered and unindexed and it is mutable
# - Set items are unordered,and do not allow duplicate values.
# - Unordered means that the items in a set do not have a defined order.
# - Set items can appear in a different order every time you use them,and
# cannot be referred to by index or key.
# - A set is created by placing all the items (elements) inside curly braces
# {},separated by comma,or by using the built-in set() function.
# - It can have any number of items and they may be of different types
# (integer,float,tuple,string,etc).But a set cannot have mutable elementals
# like lists,sets or dictionaries as its elements
# - Union                 = Combine Element of A and B
# - intersection          = Common Element of A and B
# - differnce             = A - B
# - symmertric_differnce  = Removes the commom elements of A and B
# - disjoint              = when there is no commom element in A and B
# - issubset()            = B = {1,2,3} A ={1,2} A is the subset of B
# - issuperset()          = B is the superset of A
# - frozenset()           = Immutable. In dict it will take only keys
# METHOD
# - add
# - update
# - clear
# - copy
# - remove  undefined element error
# - discard undefined element no error
# - pop     Removes random element
# - note

# %%
# my_set={8,2.5,"str",[8,5,6]} #Error: unhasable type: 'list',set,dict also
my_set={8,2.5,"str",(1,3)}
print(my_set)
#Create a empty set
my_set3 = set()
#Add
my_set.add("mahesh")
print(my_set)
#update
my_set.update(["1",3,4,56,8,9])
print(my_set)
#clear 
my_set.clear()
print(my_set)
#copy
my_set= {'mahesh','mahesh', 2.5, 3, 4, 8, 9, 'str', '1', 56, (1, 3)}
my_set1={}
my_set1 = my_set.copy()
print(my_set1)
#remove
my_set1.remove(3)
print(my_set1)
my_set1.discard('mahesh')
print(my_set1)
#pop
my_set1.pop()
print(my_set1)
#Frozenset
dictionary_1
# Out:
# {8, 2.5, (1, 3), 'str'}
# {'mahesh', 2.5, 8, 'str', (1, 3)}
# {'mahesh', 2.5, 3, 4, 8, 9, 'str', '1', 56, (1, 3)}
# set()
# {'mahesh', 2.5, 3, 4, 8, 9, 'str', '1', 56, (1, 3)}
# {'mahesh', 2.5, 4, 8, 9, 'str', '1', 56, (1, 3)}
# {2.5, 4, 8, 9, 'str', '1', 56, (1, 3)}
# {4, 8, 9, 'str', '1', 56, (1, 3)}

# %%
#100. Create two sets of your chocic.
#a. union,intersection, differnence of both sets(a-B &B-a), symmetric differnece
set_1 = {1,2,3,4,5}
set_2 = {2,5,6,7,8,9}
set_union = set_1.union(set_2)
print(f"set_union:{set_union}")
set_intersection = (set_1.intersection(set_2))
print(f"set_intersection: {set_intersection}")
set_diffA_B = set_1.difference(set_2)
print(f"set_diffA_B: {set_diffA_B}")
set_diffB_A = set_2.difference(set_1)
print(f"set_diffB_A: {set_diffB_A}")
set_symmetric = set_1.symmetric_difference(set_2)
print(f"set_symmetric:{set_symmetric}")
# Out:
# set_union:{1, 2, 3, 4, 5, 6, 7, 8, 9}
# set_intersection: {2, 5}
# set_diffA_B: {1, 3, 4}
# set_diffB_A: {8, 9, 6, 7}
# set_symmetric:{1, 3, 4, 6, 7, 8, 9}

# %%
#101. Create two sets  one being a subset of the other
# a.Check and print whether the first set is a subset of the second
# b. Whether the second set us a superset of the first
# c. check membership of an elemnt that is not in either set
set_3 = {5,6,7,8,9}
set_4 = {7,8,10,1,2}
set_5 = {5,6,7,8,9,1}
set_6 = {7,8,1}
set_issubset = set_3.issubset(set_4)
print(f"set_issubset:{set_issubset}")
set_issuperset = set_3.issuperset(set_4)
print(f"set_issuperset:{set_issuperset}")
set_issubset1 = set_5.issubset(set_6)
print(f"set_issubset:{set_issubset1}")
set_issuperset2 = set_5.issuperset(set_6)
print(f"set_issuperset:{set_issuperset2}")
# Out:
# set_issubset:False
# set_issuperset:False
# set_issubset:False
# set_issuperset:True

# %%
#102. a.Convert the list to set
list_set = [1,"abc",3.45,("str","tuple")]
list_set_conv = set(list_set)
for i in list_set:
    print(f"list_set_conv: {i}")
#b.Remove the duplicates
set_dupliates = {1,2,"1","1",5,6,("str","tuple"),("str","tuple")}
print(f"set_dupliates: {set_dupliates}")
#C Convert the set to list
set_list = (1,"abc",3.45,("str","tuple"))
Set_list_conv = list(set_list)
print(f"Set_list_conv:{Set_list_conv}")
# Out:
# list_set_conv: 1
# list_set_conv: abc
# list_set_conv: 3.45
# list_set_conv: ('str', 'tuple')
# set_dupliates: {1, 2, 5, 6, ('str', 'tuple'), '1'}
# Set_list_conv:[1, 'abc', 3.45, ('str', 'tuple')]

# %%
#103 create a empty set and perform the operations
empty_set=set()
#add at least three elements to it
empty_set.add("Mahesh")
empty_set.update([1,2,4])
print(empty_set)
# b) Remove an element using .remove()
# c) Discard an element using .discard()
# d) Try to remove a non-existent element without error
# Out:
# {'Mahesh', 2, 4, 1}

# %%
#104. Create a frozenset using any list of values and print that frozen set
list_foren = [5,6,24,9]
frozenset(list_foren)
# Out:
# frozenset({5, 6, 9, 24})

# %%
# 105.Create two frozensets of your choice. Write a program to:

# a) Find and print the union
# b) Find and print the intersection
# c) Find and print the difference
# d) Check and print if one frozenset is a subset of the other
list_foren1 = [5,6,24,9,11]
frozenset1 = frozenset(list_foren1)
print(frozenset1)
list_foren2 = [5,6,24,9,10]
frozenset2 = frozenset(list_foren2)
print(frozenset2)
frozenset_union = frozenset1.union(frozenset2)
print(f"frozenset_union: {frozenset_union}")
frozenset_intersection = frozenset1.intersection(frozenset2)
print(f"frozenset_intersection: {frozenset_intersection}")
frozenset_difference = frozenset1.difference(frozenset2)
print(f"frozenset_difference:{frozenset_difference}")
frozenset_subset = frozenset1.issubset(frozenset2)
print(f"frozenset_subset:{frozenset_subset}")
# Out:
# frozenset({5, 6, 9, 11, 24})
# frozenset({5, 6, 9, 10, 24})
# frozenset_union: frozenset({5, 6, 9, 10, 11, 24})
# frozenset_intersection: frozenset({24, 9, 5, 6})
# frozenset_difference:frozenset({11})
# frozenset_subset:False
