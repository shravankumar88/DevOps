# %% [markdown]
# (NTS)STRING - Immutable(can`t changable)
# - Varibale Index name = "Python" print(name[-2])
# - Slicing print(name[2:4])
# - replace(old,new) upper()  lower()  Captitalize Title
# - count(substring) returns the number of times a substring appers in the string
# - strip(): Removes leading and traliing whitespace from the string
# - lstrip() & rstrip()
# - startswith () & endswith()
# - find (-1 for nothing finding in text)
# - index (Error if doesn`t find that letter)
# - isdigit()

# %%
#Varibale Index
name = "Python"
print(name[-2])
#Slicing
print(name[2:4])
#Palindrome
Palindrome = input("Enter the name")
if Palindrome==Palindrome[::-1]:
    print("it is Palindrome")
else:
    print("it is not Palindrome")
#startswith
startswith_contain = "python"
print(startswith_contain.startswith("p"))

# %%
#find
find_string = "Enter anything and the index"
print(find_string.find("a"))
find_string1 = "Enter anything and the index"
print(find_string.find("n",5)) #it starts check with index 5 to find the n
print(find_string.find("n",5,15))
index_string = "Enter anything and the index"
print(index_string.index("a"))

# %%
#if you want to find the index of all repeated letters
repeated_letters = "Enter anything and the index"
for i in range(len(repeated_letters)):
    if repeated_letters[i] == "e":
        print(i)

# %%
#62.Take a string paragraph replace is with are and the with that
replace_str = "Take a string paragraph replace are and that"
replace_str1 = replace_str.replace("are", "is").replace("that","with")
print(replace_str1)

# %%
#64'''Ask the userto enter a sentence and print the senetence with all the
#letters converted to uppercase

convert_uppercase=input("Enter the sentance")
convert_uppercase1 = convert_uppercase.upper()
print(convert_uppercase1)

# %%
#65 Ask the userto enter a sentence and print the senetence with all the
#letters converted to lowercase

convert_lowercase=input("Enter the sentance")
convert_lowercase1 = convert_lowercase.lower()
print(convert_lowercase1)

# %%
#63 Ask the user to enter a senetence and print it so that the first letter 
# of each words is uppercase and reset the letters in each works are lowercase
user_str = input("Enter a senetence")
print(user_str)
uppercase1 = user_str.title()
print(uppercase1)

# %%
#66 Ask the user to enter a word how many vowels it contains
text1 = input("Enter the sentence")
vowels = ["aeiou"]
count=0
for i in text1:
    count+=text1.count(i)
print(count)

# %%
#67 Ask the user to enter a sentence and return the same sentences 
# without spaces at the beginning and end
no_space = input("Enter the sentence")
no_space1 = no_space.strip(" ")
print(no_space)
print(no_space1)

# %%
#68 Ask the user to enter a sentenase and a word.
# Determine if the senetnce is ends with that word.
#print"Yes"if it does otherwise "No"
determine = input("Enter the sentence?Yes/No:")
if determine.endswith("word"):
    print(f"{determine}Yes")
else:
    print(f"{determine}No")

# %%
#69 Enter a word and check it reads the same forwards and backwards
check = input("Enter the word")
if check == check[::-1]:
    print("it is palindrome")
else:
    print("it is not")

# %%
#70 Enter a senetnce and print it so that only the very frist letter 
# of the sentence is uppercase and reset is lowercase
user_str = input("Enter a senetence")
print(user_str)
uppercase = user_str.capitalize()
print(uppercase)

# %%
#71 Determine if the senetnces starts with that word print"Yes"if it does otherwise "No"
determine = input("Enter the sentence")
if determine.startswith("hi"):
    print("yes")
else:
    print("no")

# %% [markdown]
# - isdigit()
# - isalpha()
# - isalnum
# - format
# - split(By default it take space)
# - join (join_sentence1="".join(join_sentence))

# %%
split_sentence1 = "https://www.ggogle.com/check/split"
split_sentence2 = split_sentence1.split("/")
print(split_sentence2)
print(split_sentence2[2])
print(f"Path:{split_sentence2[3:]}")
# Out:
# ['https:', '', 'www.ggogle.com', 'check', 'split']
# www.ggogle.com
# Path:['check', 'split']

# %%
accountno_list = ["****","****","6987"]
numbers = ["1234","5678"]
for i in range(len(accountno_list)):
    if accountno_list[i]=="****":
        accountno_list[i]=numbers.pop(0)
msg_accoutnumber = " ".join(accountno_list)
print(msg_accoutnumber)
# Out:
# 1234 5678 6987

# %%
#isdigit example adding the numbers in string
number = "a1b2c3"
sum =0
for i in number:
    if i.isdigit():
        sum+=int(i)
print(sum)
# Out:
# 6

# %%
#72. Ask the user for input and check if it’s a number using isdigit(). 
# If it’s a number, print it doubled.
is_digit = input("Enter the number")
print(is_digit.isdigit())

# %%
#73. Given a string "Mahesh123", extract and print only the digit parts.
extract_num = "Mahesh123"
sum =0
for i in extract_num:
    if i.isdigit():
        sum+=int(i)
print(sum)
# Out:
# 6

# %%
#74. Ask the user to input a name. 
# Check if the name contains only alphabets using isalpha().
contains_alphabets = input("Enter the name with numbers")
print(f"{contains_alphabets.isalpha()}:contains_alphabets ")

# %%
#75. From a list like ["Mahesh", "pavan123", "suresh", "ch3rry"], 
# print only the words that are purely alphabetic.
purely_alphabetic = ["Mahesh", "pavan123", "suresh", "ch3rry"]
for i in purely_alphabetic:
    if i.isalpha():
        print(i)
# Out:
# Mahesh
# suresh

# %%
#76. Ask for a username. Accept only if it's alphanumeric using isalnum().
contains_alphanumeric = input("Enter the name with numbers")
for i in contains_alphanumeric:
    if i == i.isalnum():
        print(f"{i}, Yes it is alphanumeric ")
    else:
        print(f"{i}, Yes it is not alphanumeric ")
# Out:
# H, Yes it is not alphanumeric
# i, Yes it is not alphanumeric
# 1, Yes it is not alphanumeric
# 2, Yes it is not alphanumeric
# 3, Yes it is not alphanumeric

# %%
#77. Take a list of strings, keep only those that 
# contain letters and/or digits but no special characters.
no_spec_char = ["python","life123","learn", "45days", "che#k"]
for i in no_spec_char:
    if i.isalnum():
        print(i)
# Out:
# python
# life123
# learn45days

# %%
#78. Ask the user for their name and age, then print a formatted greeting.
print("learn {} {}".format("python", 45))
format_names = ["h1","h2","h3"]
for i in format_names:
    print("try this {}".format(i))
# Out:
# learn python 45
# try this h1
# try this h2
# try this h3

# %%
#79. Ask the user to input a sentence and split it into words using split().
split_sentence = "try to split the sentence"
print(split_sentence.split())
# Out:
# ['try', 'to', 'split', 'the', 'sentence']

# %%
#80. Given a list like ["Python", "is", "Powerful"], 
# join the words into a sentence with spaces.
join_sentence = ["Python", "is", "Powerful"]
join_sentence1="".join(join_sentence)
print(join_sentence1)
join_sentence2="-".join(join_sentence)
print(join_sentence2)
# Out:
# PythonisPowerful
# Python-is-Powerful

# %%
#81. Ask the user to input several words, 
# split them, and then join them using -.
join_sentence3 = input("Enter the name with numbers")
join_sentence4=join_sentence3.split()
print(join_sentence4)
print(" ".join(join_sentence4))
join_sentence5=join_sentence3.split("/")
print(join_sentence5)
# Out:
# ['python', 'is', 'learn']
# python is learn
# ['python is learn']
