# %% [markdown]
# Numpy
# -

# %%
#Import numpy module with alias np
import numpy as np

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#
# File c:\Users\shravankumart\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\__init__.py:49
#      42     _module = _err.name
#      43     raise ImportError(
#      44         f"C extension: {_module} not built. If you want to import "
#      45         "pandas from the source directory, you may need to run "
#      46         "'python setup.py build_ext' to build the C extensions first."
#      47     ) from _err
# ---> 49 from pandas._config import (
#      50     get_option,
#      51     set_option,
#      52     reset_option,
#      53     describe_option,
#      54     option_context,
#      55     options,
#      56 )
#      58 # let init-time option registration happen
# ...
