# %% [markdown]
# > Machine Learning
# 1. It is a subset of AI that is mainly concerned with the developent of algorithms which allow a computer to learn from the data and past experience on their own.
# 2. What is Data? - Data is Raw facts!
#     - Numerical Data  like 123
#     - Categorical Data like YES/NO MALE/FEMALE/Others
#     - Time Series Data like weather report how it is Morning from Evenig
#     - Text Data like [text]
# 3. Where we will get the Data?
#     - Kaggle
#     - Web scraping
#     - Thrid-Party Companies
#     - Five of the most popluar ML dataset resources:
#         - Google, Microsoft,AWS,UCI,DATA.GOV
# 4. What is a DATA SET? - Consider a Table with Rows and Columns with info
# >Types of Machine Learning
# 1. Supervised - Task Driven (Predict next value)
# 2. Unsupervised - DATA Driven (Identify Clusters)
# 3. Reinforcement - Learn From Mistakes
#
# ![image.png](attachment:image.png)
#
# > Steps 1: Data gathering:
# - Gathering Data from varios Thrid-party companies,websites,institutions like
# ![image-2.png](attachment:image-2.png)
# > Step 2 : Date Preprocessing
# - How do you know the data is clean like NULLVales,specical charaters etc.,
# - It is the process of transforw=ming raw data into an understandabale format.
# - Major Tasks in Data Preprocessing:
#     - Data Cleaning
#     - Data Integration
#     - Data Reduction
#     - Data Transformation
#     > Tools and Libraries in Python
#     1. Libraries
#         - Pandas
#         - Numpy
#     2. Tools
#         - ETL Tools
#         - Excel
# > Step3: Data Visualization
# - It is graphical representataion of information and data. By using visual elements like charts,graphs and maps
#     > Tools and Libraries in Python
#     1. Libraries
#         - Matplotlib
#         - Seaborn
#         - Plotly
#     2. Tools
#         - Powerbi
#         - Tableau
# > Step4: Data Modeling
# 1. Selecting the Algorithm
#     -  After the data visulization we get know which algorthiim we need to chooose like defined above Supervised.Unsupervised,Reinformants
# 2. Training the Model
# 3. Testing the model
#     > Tools
#     1. sklearn(scikits learn)
# > Step5: Deployment
# - It means the integration of the model into an existing production environment which can take in an input and return an output that can be used in making pratical business decisions.
#     > Deployment using
#     1. Diango Or Flask
#     2. SQL
#     3. Github
#     4. Aws/Azure/GCP
#     5. Heroku
